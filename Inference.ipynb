# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_spd_matrix  #to generate covariance matrices
from scipy.stats import special_ortho_group
from numpy.random import dirichlet
from scipy.stats import invwishart, matrix_normal
from numpy.linalg import inv,det
from numpy import sqrt
from tqdm import trange

seed = 123
np.random.seed(seed)

# %% [markdown]
# ## INFERENCE AND GIBBS SAMPLER
#
# Let's call $D$ the number of features of the data vectors, and $K$ the number of hidden states.
#
# $\pi_k$ is the $k^{th}$ row of the transition matrix and it is a vector containing the probabilities to reach another discrete state starting from $z = k$.\
# Thus, it is a vector of the type: $\pi_k = (p_{k,0}, p_{k,1},\dots,p_{k,K-2},p_{k,K-1})$.
#
# The problem we are facing is conceptually similar to the *mixture of gaussians model* except that there are $K$ vectors like $\pi_k$, while in the *mixture of gaussians model* there is only one.
# So, we can write $P(z_t = q | z_{t-1} = k) = p_{k,q}$ or $P(z_t | z_{t-1} = k) = cat(\pi_k)$ for all $k$s.
#
# We choose as prior for every $\pi_k$ a Dirichlet distribution i.e. the conjugate prior of the categorical:
# $\boldsymbol{\pi}_k | \alpha_k \sim \operatorname{Dir}\left(\boldsymbol{\alpha}_k\right)$ with $\boldsymbol{\alpha_{k}} = \boldsymbol{1} \in \mathbb{R}^{K}$ for an uniformative prior.\
# In this way the posterior is again a Dirichlet:
# $P(\boldsymbol{\pi}_k | z_t, z_{t-1} = k) = \operatorname{Dir}\left(\boldsymbol{\alpha}_k + \boldsymbol{n}_k \right)$
# where $\boldsymbol{n}_k = (n_{k,0}, \dots, n_{k,K-2}, n_{k,K-1})$ is the vector containing the number of times is observed a transition $k \rightarrow q$ $\forall q$.
#
# It looks like the whole procedure is an hybrid between *soft clustering* and *multivariate bayesian regression*: given all the experimental data $(\boldsymbol{X},\boldsymbol{Y})$ we want to divide them in $K$ clusters obtaining
# $(\boldsymbol{X^{(k)}},\boldsymbol{Y^{(k)}})\; \forall k$. Each cluster is defined by two matrices $A_k$ and $Q_k$ and a vector $b_k$ and we want to perform a linear regression to find them. Eventually we also want the probability that the next point will be sampled from a given cluster i.e. the transition matrix and the distribution of the variable $z_t$.
#
# Let's go go on with the $K$ linear regressions (one for each cluster). It is worth to notice that the linear regreassions are separated: $X^{(k)}$ does not interact with $X^{(q)}$ if $k \neq q$. What we mean is that at this point the math of the problem says that we are going to perform linear regressions on $K$ systems of the form: $X_{s}^{(k)} = X_{s - 1}^{(k)} A_k + b_k$, where the time $s$ is redifined on the subset $X^{(k)}$ of $X$.
# We want to perform the regressions in homogeneous coordinates, so, if $T_k$ is the number of samples of the cluster $k^{th}$ cluster, the dynamic becomes $Y_{s}^{(k)} = X_{s - 1}^{(k)} A_k$, but now $Y_{s}^{(k)} \in \mathbb{R}^{(T_k - 1)xD}$, $X_{s - 1}^{(k)} \in \mathbb{R}^{(T_k - 1)x(D + 1)}$ and $A_{k} \in \mathbb{R}^{(D+1) x D}$ and its last row is the vector $b_k$.
#
# Let's write something more on the bayesian linear regression. We are dropping the index $k$ but it must be understood that everything is done for the $k^{th}$ bayesian linear regression.
# We choose as priors: $P(A|Q) = \mathcal{M} \mathcal{N}_{(D+1)xD}(M_0,Q,\Lambda_{0}^{-1})$ where $M_{0} \in \mathbb{R}^{(D+1)xD}$ and $\Lambda_{0}^{-1} \in \mathbb{R}^{(D+1)x(D+1)}$ and also $P(Q) = \mathcal{W}^{-1}\left(\mathbf{V}_0, \boldsymbol{\nu}_0\right)$
# where $\mathbf{V}_0$ has the same dimensions as $Q$ ($Q \in \mathbb{R}^{DxD}$) and it is positive definite, $\boldsymbol{\nu}_0$ is a number.
# Using the priors above, the posteriors are:
#
# $$
# P(\boldsymbol{Q} |\mathbf{Y}, \mathbf{X}) \sim \mathcal{W}^{-1}\left(\mathbf{V}, \nu \right)\\
# P(\mathbf{A} | \mathbf{Y}, \mathbf{X}, \mathbf{Q}) \sim \mathcal{M} \mathcal{N}_{D, D+1}\left(\mathbf M,\mathbf{Q}, \mathbf{\Lambda}^{-1}\right)
# $$
#
# where:
# \begin{aligned}
# & \mathbf{V}=\mathbf{V}_0+\left(\mathbf{Y}-\mathbf{X M}\right)^{\top}\left(\mathbf{Y}-\mathbf{X M}\right) + \left(\mathbf{M} -\mathbf{M}_0\right)^{\top} \mathbf{\Lambda}_0\left(\mathbf{M} -\mathbf{M}_0\right) \\
# & \boldsymbol{\nu} =\boldsymbol{\nu}_0 + T \\
# & \mathbf{M} = (\mathbf{X}^{\top} \mathbf{X} +\mathbf{\Lambda}_0)^{-1} (\mathbf{X}^{\top} \mathbf{Y} +\mathbf{\Lambda}_0 \mathbf{M}_0)\\
# & \mathbf{\Lambda}=\mathbf{X}^{\top} \mathbf{X} + \mathbf{\Lambda}_0
# \end{aligned}
#
# We will firtstly compute $\nu$ and $\Lambda$ and then plug them in the other two parameters.
# Eventually we have to sample the the whole vector $z_t$ from its posterior, calling $x_t$ the $t^{th}$ column of $X$ and $y_t$ the $t^{th}$ column of $Y$, we can write:
#
# $$
# \operatorname{P}\left(z_t=k | z_{t-1},ALL\right)=\frac{r_{t k}}{\sum_k r_{t k}} \; \text{where} \;
# r_{t k}=p_{z_{t-1},k}\left|Q_k\right|^{-1 / 2} \exp \left\{-\frac{1}{2}\left(\mathbf{y}_t - \mathbf{x}_{t} A_k \right) Q_k^{-1}\left(\mathbf{y}_t - \mathbf{x}_{t} A_k \right)^{\top} \right\}\\
# \text{or equivalentely} \; z_t \sim \operatorname{cat}\left(p_t^{\prime}\right) \; \text{where} \; p_t^{\prime} = \operatorname{P}\left(z_t | z_{t-1},ALL\right) \; \forall t
# $$
#
# In some sense it is a probability that takes into account the distance between the cluster labelled $k$ and the point $x_t$.
# The whole procedure must be carried on till convergence.

# %% [markdown]
# ## Data preparation
#
# Uploading and preparing data for homogeneous coordinates.

# %%
#uploading data
X_data = np.load('./simulation/x.npy')
z_data = np.load('./simulation/z.npy')
A_data = np.load('./simulation/A.npy')
b_data = np.load('./simulation/b.npy')
Q_data = np.load('./simulation/Q.npy')
PI_data = np.load('./simulation/P.npy')

n_iterations = 1000                                           #number of iterations in the Gibbs sampler
burn_out = 500
K = np.unique(z_data).size
D = X_data.shape[0]
T = X_data.shape[1]

#preparing data
X = X_data[:, 0:T-1]                                          #this X_{t-1} so times run between [0,T-1]

Y = X_data[:, 1:T]                                            #this is X_t so times run between [1,T], dimensions D x (T-1)


Y = Y.T
X = X.T

print('X mean:',  X.mean(axis = 0),'\n')
print('Y mean:',  Y.mean(axis = 0),'\n')

#adding a column of ones to X.T
X = np.column_stack((X,np.ones(T-1)))                          #dimensions (T-1)x(D+1)

#now A is (D+1)xD and its last row is b, Y is (T-1)xD, X is (T-1)x(D+1) 
print('X dimensions:', X.shape,'\n')
print('Y dimensions:', Y.shape,'\n')

for k in range(K):
    print('########### k = %d ###################' %k,'\n')
    
    print('A%d' %k, '\n')
    print(A_data[k],'\n')
    
    print('Q%d' %k, '\n')
    print(Q_data[k],'\n')
    
    print('b%d' %k, '\n')
    print(b_data[k],'\n')
    
print('###### PI #########','\n')
print(PI_data,'\n')
# Out:
# X mean: [-1.58513843 -4.49309578]
#
# Y mean: [-1.56244592 -4.448683  ]
#
# X dimensions: (1999, 3)
#
# Y dimensions: (1999, 2)
#
# ########### k = 0 ###################
#
# A0
#
# [[ 0.73641574 -0.67652927]
#  [ 0.67652927  0.73641574]]
#
# Q0
#
# [[ 2.5788794  -0.08195534]
#  [-0.08195534  0.56369603]]
#
# b0
#
# [-2.42667924 -0.42891263]
#
# ########### k = 1 ###################
#
# A1
#
# [[-0.18463408  0.98280733]
#  [-0.98280733 -0.18463408]]
#
# Q1
#
# [[2.14784643 0.57716914]
#  [0.57716914 0.51084878]]
#
# b1
#
# [ 1.26593626 -0.8667404 ]
#
# ########### k = 2 ###################
#
# A2
#
# [[ 0.33065458 -0.94375185]
#  [ 0.94375185  0.33065458]]
#
# Q2
#
# [[ 1.48623069 -1.05231422]
#  [-1.05231422  1.43339847]]
#
# b2
#
# [-0.67888615 -0.09470897]
#
# ###### PI #########
#
# [[0.25 0.5  0.25]
#  [0.1  0.1  0.8 ]
#  [0.6  0.2  0.2 ]]

# %% [markdown]
# ## Inference

# %%
def sample(n_iterations : int,K : int,X_data):

    """ 
    n_iterations : samples to generate
    K : int, number of latent states
    X_data : array-like with shape (n_features,n_samples)
    """

    D = X_data.shape[0]
    T = X_data.shape[1]

    #preparing data
    X = X_data[:, 0:T-1]                                          #this X_{t-1} so times run between [0,T-1]
    Y = X_data[:, 1:T]                                            #this is X_t so times run between [1,T], dimensions D x (T-1)


    Y = Y.T
    X = X.T
    X = np.column_stack((X,np.ones(T-1)))             # dummy variable


    #instantiting everything
    z = np.zeros((n_iterations, T - 1), dtype = np.int8)
    N = np.zeros((K,K))

    Q = np.zeros((n_iterations, K, D, D))             #covariance matrix
    L = np.zeros((n_iterations, K, D + 1, D + 1))     #lambda parameter for matrix normal
    V = np.zeros((n_iterations, K, D, D))             #V parameter for the inverse Wishart
    nu = np.ones((n_iterations, K))*D                 #nu parameter for inverse wishart, already initialised
    A = np.zeros((n_iterations, K, D + 1, D)) 
    M = np.zeros((n_iterations, K, D + 1, D))         #mean matrix for matrix normal
    PI = np.zeros((n_iterations, K, K))               #transition matrix
    alp = np.ones(K)                                  #parameter for the dirichlet

    #defining dictionary of indices for X_k, Y_k
    keys = np.array([str(k) for k in np.arange(K)]) 
    k_indices = dict.fromkeys(keys)

    #ITERATION ZERO             
                
    #randomly sample z from uniform dist
    z[0] = np.random.choice(K, size = T - 1, p = None)

    #filling the matrix N
    for i in range(T - 2):
        N[z[0,i],z[0,i+1]] += 1

    for k in range(K): 
                                                                            #nu has already been initialised
        L[0,k] = make_spd_matrix(D + 1, random_state = seed)                  
        V[0,k] = make_spd_matrix(D, random_state = seed)
                                                                            #M has already been initialised
        k_indices[str(k)] = np.where(z[0,:] == k)[0]                          #indices where z = k
        PI[0,k] = dirichlet(alpha = alp, size = 1).flatten()                  #first approximation of all rows of transition matrix
        Q[0,k] = invwishart.rvs(df = nu[0,k], scale = V[0,k])                 #first approximation of variance matrix
        A[0,k] = matrix_normal.rvs(mean = M[0,k],\
                                    rowcov = inv(L[0,k]), colcov = Q[0,k])

    #ITERATION FROM ONE TO THE END

    for it in trange(1, n_iterations):
        for k in range(K):
            
            X_k = X[k_indices[str(k)],:]                                       #selecting X_k and Y_k
            Y_k = Y[k_indices[str(k)],:]
                
            PI[it,k] = dirichlet(alpha = alp + N[k,:], size = 1).flatten() 
                
            #updating L_k, nu_k, A_k, V_k, Q_k, Mn_k, A_k
            L[it,k] = X_k.T @ X_k +  L[0, k]
            nu[it,k] = nu[0,k] + Y_k.shape[0]
                
            M[it,k] = inv(L[it,k]) @ (X_k.T @ Y_k + L[0,k] @ M[0,k])

            V[it,k] = V[0,k] + (Y_k - X_k @ M[it,k]).T @ (Y_k - X_k @ M[it,k]) +\
            (M[it,k] - M[0,k]).T @ L[0,k] @ (M[it,k] - M[0,k])

            Q[it,k] = invwishart.rvs(df = nu[it,k], scale =  V[it,k])
            A[it,k] = matrix_normal.rvs(mean = M[it,k], rowcov = inv(L[it,k]), colcov = Q[it,k])
            
        for t in np.arange(T-1):
                
            p_prime = np.array([(PI[it,z[it,t-1],k]/sqrt(det(Q[it,k]))) * np.exp(-0.5 * (Y[t,:] - X[t,:] @ A[it,k]) @ inv(Q[it,k]) @ (Y[t,:] - X[t,:] @ A[it,k]).T) for k in np.arange(K)])
            p_prime = p_prime/np.sum(p_prime)
            z[it,t] = np.random.choice(K, size = 1, p = p_prime)
                
        N = np.zeros((K,K))

        for i in range(T - 2):
            N[z[it,i],z[it,i+1]] += 1 
                
        for k in range(K):
            k_indices[str(k)] = np.where(z[it,:] == k)[0]

    return {
              "z"  : z, 
              "N"  : N, 
              "Q"  : Q, 
              "L"  : L, 
              "V"  : V, 
              "nu"  : nu, 
              "A"  : A, 
              "M"  : M, 
              "PI"  : PI, 
              "alp"  : alp
    }

# %%
samples = sample(1000,3,X_data)
# Out:
# 100%|██████████| 999/999 [02:58<00:00,  5.60it/s]

# %% [markdown]
# ## Showing results
#
# the numeration of the three clusters is arbitrary, and the one found by the sampler do not coincides with the one estabilished while generating trajectories.

# %%
A_inf = samples['A'][burn_out:,:,:-1,:]     #inferred A matrix for all the iterations after burn_out
b_inf = samples['A'][burn_out:,:,-1,:]      #inferred B matrix for all the iterations after burn_out 
PI_inf = samples['PI'][burn_out:]           #inferred PI matrix for all the iterations after burn_out 
Q_inf = samples['Q'][burn_out:]

# %%
#function to plot A and Q 

def hist_AQ(mat,number_k,num_bins, label):
    fig,axs = plt.subplots(2,2,figsize = (15,10))
    for i in range(D):
        for j in range(D):
            hist, bin_edges = np.histogram(mat[:,number_k,i,j], density = True, bins = num_bins)
            bin_centers = (bin_edges[1:] + bin_edges[:-1])/2
            labels = np.array([str(round(l,4)) for l in bin_edges])
            w = (max(bin_edges) - min(bin_edges))/num_bins
            
            mean = np.dot(bin_centers, hist)/np.sum(hist)
            mean_x2 = np.dot(bin_centers**2, hist)/np.sum(hist)
            std = np.sqrt(mean_x2 - mean**2)

            text = ' ${}_{}[{},{}] = {:.4f} +- {:.4f}$'.format(label, number_k, i, j, mean, std)
    
            axs[i,j].set_title('$ %c_{%d}[%d,%d] $' %(label,number_k,i,j))       
            axs[i,j].text(0.99,0.99,text, horizontalalignment='right', verticalalignment='top', transform=axs[i,j].transAxes, fontsize = 12)
            axs[i,j].bar(bin_centers, hist, color = 'blue', alpha = 0.3, edgecolor = 'red', linewidth = 2, width = w, align = 'edge')
            axs[i,j].set(xticks=bin_edges, xticklabels=labels)
    
    plt.show()
    
#histogram to plot PI

def hist_PI(mat,num_bins):
    fig,axs = plt.subplots(3,3,figsize = (15,10), tight_layout = True)
    for i in range(K):
        for j in range(K):
            hist, bin_edges = np.histogram(mat[:,i,j], density = True, bins = num_bins)
            bin_centers = (bin_edges[1:] + bin_edges[:-1])/2
            labels = np.array([str(round(l,4)) for l in bin_edges])
            w = (max(bin_edges) - min(bin_edges))/num_bins
            
            mean = np.dot(bin_centers, hist)/np.sum(hist)
            mean_x2 = np.dot(bin_centers**2, hist)/np.sum(hist)
            std = np.sqrt(mean_x2 - mean**2)

            text = ' $PI[{},{}] = {:.4f} +- {:.4f}$'.format(i,j,mean, std)
     
            axs[i,j].set_title('$ PI[%d,%d] $' %(i,j))
            axs[i,j].text(0.99,0.99,text, horizontalalignment='right', verticalalignment='top', transform=axs[i,j].transAxes, fontsize = 12)
            axs[i,j].bar(bin_centers, hist, color = 'blue', alpha = 0.3, edgecolor = 'red', linewidth = 2, width = w, align = 'edge')
            axs[i,j].set(xticks=bin_edges, xticklabels=labels)
    
    plt.show()
    
#function to plot b
def hist_b(vec,number_k,num_bins):
    
    fig,axs = plt.subplots(D,figsize = (8,10))
    for i in range(D):

        hist, bin_edges = np.histogram(vec[:,number_k,i], density = True, bins = num_bins)
        bin_centers = (bin_edges[1:] + bin_edges[:-1])/2
        labels = np.array([str(round(l,4)) for l in bin_edges])
        w = (max(bin_edges) - min(bin_edges))/num_bins
         
        mean = np.dot(bin_centers, hist)/np.sum(hist)
        mean_x2 = np.dot(bin_centers**2, hist)/np.sum(hist)
        std = np.sqrt(mean_x2 - mean**2)

        text = ' $b_{}[{}] = {:.4f} +- {:.4f}$'.format(number_k,i,mean, std)

        axs[i].set_title('$b_{%d}[%d]$' %(number_k,i))
        axs[i].text(0.99,0.99,text, horizontalalignment='right', verticalalignment='top', transform=axs[i].transAxes, fontsize = 12)
        axs[i].bar(bin_centers, hist, color = 'blue', alpha = 0.3, edgecolor = 'red', linewidth = 2, width = w, align = 'edge')
        axs[i].set(xticks=bin_edges, xticklabels=labels)

    plt.show()

# %% [markdown]
# # k = 0

# %%
hist_AQ(A_inf, 0, 6, 'A')

# %%
hist_AQ(Q_inf, 0, 6, 'Q')

# %%
hist_b(b_inf, 0, 6)

# %% [markdown]
# ## K = 1
#
# $k = 1$ and $k = 2$ are swapped in the following histograms.

# %%
hist_AQ(A_inf, 1, 6, 'A')

# %%
hist_AQ(Q_inf, 1, 6, 'Q')

# %%
hist_b(b_inf, 1, 6)

# %% [markdown]
# ## K = 2

# %%
hist_AQ(A_inf, 2, 6, 'A')

# %%
hist_AQ(Q_inf, 2, 6, 'Q')

# %%
hist_b(b_inf, 2, 6)

# %% [markdown]
# ## PI

# %%
hist_PI(PI_inf,6)
